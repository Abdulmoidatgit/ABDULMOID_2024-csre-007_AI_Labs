# %% [markdown]
# **Example 1 – Creating and Accessing Lists**

# %%
# Example 1 – Creating and Accessing Lists
# A list is defined with square brackets [] and items separated by commas.

robots = ["Alpha", "Beta", "Gamma"]
print("Robot List:", robots)          # print the whole list
print("First Robot:", robots[0])      # index 0 = first item
print("Second Robot:", robots[1])
print("Last Robot:", robots[-1])      # -1 = last item from the end
# Out:
# Robot List: ['Alpha', 'Beta', 'Gamma']
# First Robot: Alpha
# Second Robot: Beta
# Last Robot: Gamma

# %% [markdown]
# **Example 2 – Modifying a List**

# %%
# Example 2 – Modifying a List
# .append() adds to the end, .remove(value) deletes the first matching item.

robots.append("Delta")     # add a new robot
robots.remove("Beta")      # remove a robot named 'Beta'
print("Updated Robot List:", robots)
# Out:
# Updated Robot List: ['Alpha', 'Gamma', 'Delta']

# %% [markdown]
# **Practice for lists goes here**

# %%
# TODO: Your practice for lists goes here
fruits = ["apple", "banana", "mango", "orange", "grapes"]

# 1) Print first and last fruit
print("First fruit:", fruits[0])
print("Last fruit:", fruits[-1])

# 2) Add and remove an item
fruits.append("pineapple")   # add a fruit
print("After adding pineapple:", fruits)

fruits.remove("banana")      # remove a fruit
print("After removing banana:", fruits)

# 3) Print the final list
print("Final list of fruits:", fruits)
# Out:
# First fruit: apple
# Last fruit: grapes
# After adding pineapple: ['apple', 'banana', 'mango', 'orange', 'grapes', 'pineapple']
# After removing banana: ['apple', 'mango', 'orange', 'grapes', 'pineapple']
# Final list of fruits: ['apple', 'mango', 'orange', 'grapes', 'pineapple']

# %% [markdown]
# **Example 3 – Creating and Accessing a Dictionary**

# %%
# Example 3 – Creating and Accessing a Dictionary
robot = {"name": "Alpha", "battery": 80, "status": "Active"}

print("Robot Name:", robot["name"])     # access by key
print("Battery Level:", robot["battery"])
print("Status:", robot["status"])
# Out:
# Robot Name: Alpha
# Battery Level: 80
# Status: Active

# %% [markdown]
# **Example 4 – Updating a Dictionary**

# %%
# Example 4 – Updating a Dictionary
robot["battery"] = 95              # update a value
robot["task"] = "Line Following"   # add a new key-value pair
print("Updated Robot Info:", robot)
# Out:
# Updated Robot Info: {'name': 'Alpha', 'battery': 95, 'status': 'Active', 'task': 'Line Following'}

# %% [markdown]
# **Practice for dictionahereries goes**

# %%
# TODO: Your practice for dictionahereries goes 
student = {"name": "Ali", "roll_no": 7, "score": 72}

# 1) Increase score by 5
student["score"] += 5

# 2) Add a new key 'grade'
student["grade"] = "A"  # you can decide grade logic as needed

# 3) Print the final dictionary
print("Final student record:", student)
# Out:
# Final student record: {'name': 'Ali', 'roll_no': 7, 'score': 77, 'grade': 'A'}

# %% [markdown]
# **Iterate over a list**

# %%
# For Loop – iterate over a list
robots = ["Alpha", "Gamma", "Delta"]

for r in robots:
    print("Activating Robot:", r)
# Out:
# Activating Robot: Alpha
# Activating Robot: Gamma
# Activating Robot: Delta

# %% [markdown]
# **Run until battery becomes 0**

# %%
# While Loop – run until battery becomes 0
battery = 5

while battery > 0:
    print("Battery remaining:", battery)
    battery -= 1  # decrease by 1
# Out:
# Battery remaining: 5
# Battery remaining: 4
# Battery remaining: 3
# Battery remaining: 2
# Battery remaining: 1

# %% [markdown]
# **Your practice for loops goes here**

# %%
# TODO: Your practice for loops goes here

# 1) For loop over a string
word = "ROBOT"
print("Characters in the string:")
for ch in word:
    print(ch)

# 2) While loop countdown
count = 3
print("\nCountdown:")
while count >= 1:
    print(count)
    count -= 1
print("Go!")
# Out:
# Characters in the string:
# R
# O
# B
# O
# T
#
# Countdown:
# 3
# 2
# 1
# Go!

# %% [markdown]
# **Example – Battery-based Decision**

# %%
# Example – Battery-based Decision
battery = 40

if battery > 60:
    print("Battery is Full – Ready for Mission!")
elif battery > 30:
    print("Battery is Medium – Prepare for Recharge.")
else:
    print("Battery Low – Returning to Base.")
# Out:
# Battery is Medium – Prepare for Recharge.

# %% [markdown]
# **Mini Project – Robot Battery Checker**

# %%
# Mini Project – Robot Battery Checker
# .items() lets us loop over (key, value) pairs in a dictionary

robots = {"Alpha": 75, "Beta": 20, "Gamma": 60}

for name, battery in robots.items():
    if battery > 50:
        print(name, "→ Battery OK ✅ (", battery, "%)")
    else:
        print(name, "→ Low Battery ⚠ (", battery, "%)")
# Out:
# Alpha → Battery OK ✅ ( 75 %)
# Beta → Low Battery ⚠ ( 20 %)
# Gamma → Battery OK ✅ ( 60 %)
